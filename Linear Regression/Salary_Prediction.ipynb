# %%
#dataset = https://www.kaggle.com/datasets/abhishek14398/salary-dataset-simple-linear-regression

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import kagglehub
from kagglehub import KaggleDatasetAdapter

# %%
#downloading dataset:
kagglehub.dataset_download('abhishek14398/salary-dataset-simple-linear-regression')
# Out:
# ...
# 100%|██████████| 457/457 [00:00<?, ?B/s]
# Extracting files...
# 'C:\\Users\\Lenovo\\.cache\\kagglehub\\datasets\\abhishek14398\\salary-dataset-simple-linear-regression\\versions\\1'

# %%
#importing dataset:
df = pd.read_csv(r'C:\Users\Lenovo\.cache\kagglehub\datasets\abhishek14398\salary-dataset-simple-linear-regression\versions\1\Salary_dataset.csv')
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
#defining what to predict:
x = df[['YearsExperience']]
y = df['Salary']

# %%
#splitting data for training and testing:
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)

# %%
#creating ai model:
model = LinearRegression()

# %%
#traing ai model:
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#testing ai model on testing data:
predictions = model.predict(x_test)

# %% [markdown]
# # **Evaluating AI Model**

# %%
#scatter plot of actual values vs predicted values:
plt.scatter(y_test, predictions)
plt.xlabel('actual values')
plt.ylabel('predicted values')
# Out:
# Text(0, 0.5, 'predicted values')

# %%
#histogram of residuals:
residuals = y_test - predictions
sns.histplot(residuals, kde = True)
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
#mae, rmse:
mae = metrics.mean_absolute_error(y_test, predictions)
rmse = np.sqrt(metrics.mean_squared_error(y_test, predictions))
mae_percentage = (mae / y.mean()) * 100
rmse_percentage = (rmse / y.mean()) * 100
print(f'mae percentage = {mae_percentage}')
print(f'rmse percentage = {rmse_percentage}')

#this ai model is not good but acceptable
# Out:
# mae percentage = 6.790864573443735
# rmse percentage = 8.087630924681033

# %% [markdown]
# # **Conclusion**

# %%
#what should be increased or decreased to get better salary?
pd.DataFrame(data = model.coef_, index = x.columns, columns = ['Coefficient'])

#increase in 1 year of experience increases salary by 9339$ so its better if the employee increases his salary
# Out:
#                  Coefficient
# YearsExperience  9339.081724
